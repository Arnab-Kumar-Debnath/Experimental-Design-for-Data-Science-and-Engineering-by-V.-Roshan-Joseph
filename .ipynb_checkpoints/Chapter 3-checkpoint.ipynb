# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("ggplot")
data=np.linspace(0,1,10)
data2=[0.5+0.5*np.cos(np.pi*((i-0.5)/10)) for i in range(1,11)]
R_matrix=np.zeros([len(data2), len(data2)])

# %%
def R(x, theta=0.1):
    return np.exp(-((x**2)/(theta**2)))

# %%
for i in range(len(data2)):
    for j in range(len(data2)):
        R_matrix[i,j]=R(data2[i]-data2[j])

# %%
def r(x, data=data2):
    x_R=x-data
    return R(x_R)

# %%
def s(x):
    return np.sqrt(1-r(x, data=data2).T@np.linalg.inv(R_matrix)@r(x, data=data2))

# %%
x=np.linspace(0,1,1000)

# %%
s_=[]
for i in x:
    s_.append(s(i))

# %%
plt.plot(s_)

# %%
len(data2)
# Out:
# 10

# %%
data2
# Out:
# [0.9938441702975689,
#  0.9455032620941839,
#  0.8535533905932737,
#  0.7269952498697734,
#  0.5782172325201155,
#  0.42178276747988447,
#  0.2730047501302266,
#  0.14644660940672627,
#  0.054496737905816106,
#  0.00615582970243117]

# %%
np.linalg.det(R_matrix)
# Out:
# 0.060589509497165635

# %%
R_matrix.shape
# Out:
# (10, 10)
